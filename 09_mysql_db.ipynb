# %%
import mysql.connector as ms

mydb = ms.connect(
    host = "localhost",
    user = "root",
    password = "King#123"
)

print(mydb)

# %%
cursor = mydb.cursor()

cursor.execute("CREATE DATABASE mydatabase2")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/mysql/connector/connection_cext.py:755, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     754         query = query.encode("utf-8")
# --> 755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#     758         buffered=buffered,
#     759         raw_as_string=raw_as_string,
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't create database 'mydatabase2'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[3], line 3
#       1 cursor = mydb.cursor()
# ----> 3 cursor.execute("CREATE DATABASE mydatabase2")
#
# ...

# %%
cursor.execute("SHOW DATABASES")

for x in cursor:
  print(x)
# Out:
# ('Students',)
# ('information_schema',)
# ('mydatabase2',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
mydb = ms.connect(
  host="localhost",
  user="root",
  password="King#123",
  database="mydatabase2"
)

cursor2 = mydb.cursor()

cursor2.execute("CREATE TABLE voters (name VARCHAR(255), age INT NOT NULL, city VARCHAR(255))")

# %%
cursor2.execute(" DROP TABLE customers")

# %%
cursor2.execute("ALTER TABLE voters ADD COLUMN id INT AUTO_INCREMENT PRIMARY KEY")

# %%
sql = "INSERT INTO voters (name, age, city) VALUES (%s, %s, %s)"
val = [
  ('Peter', 21, 'Lowstreet 4'),
  ('Amy', 22, 'Apple st 652'),
  ('Hannah', 18, 'Mountain 21'),
  ('Michael', 41, 'Valley 345'),
  ('Sandy', 27, 'Ocean blvd 2'),
  ('Betty', 34, 'Green Grass 1'),
  ('Richard', 32, 'Sky st 331'),
  ('Susan', 21, 'One way 98'),
  ('Vicky', 45, 'Yellow Garden 2'),
  ('Ben', 26, 'Park Lane 38'),
  ('William', 34, 'Central st 954'),
  ('Chuck', 29, 'Main Road 989'),
  ('Viola', 41, 'Sideway 1633')
]

cursor2.executemany(sql, val)

mydb.commit()

print(cursor2.rowcount, "was inserted.")
# Out:
# 13 was inserted.

# %%
cursor2.execute("SELECT * FROM voters")

myresult = cursor2.fetchall()

for x in myresult:
  print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cursor2.execute("SELECT * FROM voters")
#       3 myresult = cursor2.fetchall()
#       5 for x in myresult:
#
# NameError: name 'cursor2' is not defined

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="King#123",
  database="mydatabase2"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM voters")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Peter', 21, 'Lowstreet 4', 1)
# ('Amy', 22, 'Apple st 652', 2)
# ('Hannah', 18, 'Mountain 21', 3)
# ('Michael', 41, 'Valley 345', 4)
# ('Sandy', 27, 'Ocean blvd 2', 5)
# ('Betty', 34, 'Green Grass 1', 6)
# ('Richard', 32, 'Sky st 331', 7)
# ('Susan', 21, 'One way 98', 8)
# ('Vicky', 45, 'Yellow Garden 2', 9)
# ('Ben', 26, 'Park Lane 38', 10)
# ('William', 34, 'Central st 954', 11)
# ('Chuck', 29, 'Main Road 989', 12)
# ('Viola', 41, 'Sideway 1633', 13)

# %%
mycursor.execute("SELECT * FROM voters WHERE city ='Park Lane 38'")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Ben', 26, 'Park Lane 38', 10)

# %%
sql = "SELECT * FROM voters WHERE city LIKE '%way%'"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Susan', 21, 'One way 98', 8)
# ('Viola', 41, 'Sideway 1633', 13)

# %%
sql = "SELECT * FROM voters WHERE city = %s"
adr = ["Yellow Garden 2"]

mycursor.execute(sql, adr)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Vicky', 45, 'Yellow Garden 2', 9)

# %%
sql = "SELECT * FROM voters WHERE city = 'Central st 954' AND age = 34"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('William', 34, 'Central st 954', 11)

# %%
sql = "SELECT * FROM voters WHERE age = 41 OR age = 34 OR name = 'Vicky'"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Michael', 41, 'Valley 345', 4)
# ('Betty', 34, 'Green Grass 1', 6)
# ('Vicky', 45, 'Yellow Garden 2', 9)
# ('William', 34, 'Central st 954', 11)
# ('Viola', 41, 'Sideway 1633', 13)

# %%
sql = "SELECT * FROM voters ORDER BY name DESC"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('William', 34, 'Central st 954', 11)
# ('Viola', 41, 'Sideway 1633', 13)
# ('Vicky', 45, 'Yellow Garden 2', 9)
# ('Susan', 21, 'One way 98', 8)
# ('Sandy', 27, 'Ocean blvd 2', 5)
# ('Richard', 32, 'Sky st 331', 7)
# ('Peter', 21, 'Lowstreet 4', 1)
# ('Michael', 41, 'Valley 345', 4)
# ('Hannah', 18, 'Mountain 21', 3)
# ('Chuck', 29, 'Main Road 989', 12)
# ('Betty', 34, 'Green Grass 1', 6)
# ('Ben', 26, 'Park Lane 38', 10)
# ('Amy', 22, 'Apple st 652', 2)

# %%
sql = "SELECT * FROM voters ORDER BY age"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Hannah', 18, 'Mountain 21', 3)
# ('Peter', 21, 'Lowstreet 4', 1)
# ('Susan', 21, 'One way 98', 8)
# ('Amy', 22, 'Apple st 652', 2)
# ('Ben', 26, 'Park Lane 38', 10)
# ('Sandy', 27, 'Ocean blvd 2', 5)
# ('Chuck', 29, 'Main Road 989', 12)
# ('Richard', 32, 'Sky st 331', 7)
# ('Betty', 34, 'Green Grass 1', 6)
# ('William', 34, 'Central st 954', 11)
# ('Michael', 41, 'Valley 345', 4)
# ('Viola', 41, 'Sideway 1633', 13)
# ('Vicky', 45, 'Yellow Garden 2', 9)

# %%
mycursor.execute("SELECT * FROM voters ORDER BY age LIMIT 5 OFFSET 1")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Peter', 21, 'Lowstreet 4', 1)
# ('Susan', 21, 'One way 98', 8)
# ('Amy', 22, 'Apple st 652', 2)
# ('Ben', 26, 'Park Lane 38', 10)
# ('Sandy', 27, 'Ocean blvd 2', 5)

# %%
mycursor.execute("SELECT MIN(age) FROM voters")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# (18,)

# %%
mycursor.execute('''CREATE TABLE kids 
(id INT PRIMARY KEY,
name VARCHAR(50),
age INT NOT NULL,
fav VARCHAR(50))
''')

# %%
sql = "INSERT INTO kids (id, name, age, fav) VALUES (%s, %s, %s, %s)"
val = [
  (1,'Pete', 12, 'ice-cream'),
  (2,'Amy', 13, 'pizza'),
  (3,'Sady', 12, 'pizza'),
  (4,'nicky', 13, 'pizza'),
  (5,'Ben', 11, 'pasta'),
  (6,'miola', 12, 'ice-cream')
]

mycursor.executemany(sql, val)

mydb.commit()

# %%
mycursor.execute('''CREATE TABLE kids_address 
(name VARCHAR(50),
address VARCHAR(50),
family_members INT)
''')

# %%
sql = "INSERT INTO kids_address (name, address, family_members) VALUES (%s, %s, %s)"
val = [
  ('Pete', 'Apple st 652', 3),
  ('Amy', 'Lowstreet 4',2),
  ('Sady', 'One way 98',2),
  ('nicky', 'Park Lane 38',4),
  ('Ben', 'Ocean blvd 2',3),
  ('miola', 'Downtown city',2)
]

mycursor.executemany(sql, val)

mydb.commit()

# %%
mycursor.execute('''
SELECT kids.id,kids.name,kids_address.address 
FROM kids INNER JOIN kids_address 
ON kids.name=kids_address.name                
''')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 mycursor.execute('''
#       2 SELECT kids.id,kids.name,kids_address.address
#       3 FROM kids INNER JOIN kids_address
#       4 ON kids.name=kids_address.name
#       5 ''')
#
# File ~/.local/lib/python3.11/site-packages/mysql/connector/cursor_cext.py:313, in CMySQLCursor.execute(self, operation, params, map_results)
#     310 except (ProgrammingError, ReferenceError) as err:
#     311     raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 313 self._connection.handle_unread_result()
#     314 self.reset()
#     316 stmt = b""
#
# File ~/.local/lib/python3.11/site-packages/mysql/connector/connection_cext.py:1105, in CMySQLConnection.handle_unread_result(self, prepared)
#    1103     self.consume_results()
#    1104 elif unread_result:
# ...

# %%
mycursor.execute('''
CREATE VIEW kids_view AS 
SELECT kids.id,kids.name,kids_address.address,kids.fav
FROM kids INNER JOIN kids_address 
ON kids.name=kids_address.name  
''')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 mycursor.execute('''
#       2 CREATE VIEW kids_view AS
#       3 SELECT kids.id,kids.name,kids_address.address,kids.fav
#       4 FROM kids INNER JOIN kids_address
#       5 ON kids.name=kids_address.name
#       6 ''')
#
# File ~/.local/lib/python3.11/site-packages/mysql/connector/cursor_cext.py:313, in CMySQLCursor.execute(self, operation, params, map_results)
#     310 except (ProgrammingError, ReferenceError) as err:
#     311     raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 313 self._connection.handle_unread_result()
#     314 self.reset()
#     316 stmt = b""
#
# File ~/.local/lib/python3.11/site-packages/mysql/connector/connection_cext.py:1105, in CMySQLConnection.handle_unread_result(self, prepared)
#    1103     self.consume_results()
#    1104 elif unread_result:
# ...
