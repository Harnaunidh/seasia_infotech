# %%
f = open("text.txt", "r")
print(f.read())
f.close()
# Out:
# Hi, this is a text file
# This is the second line.
# This is the third line.

# %%
f = open("text.txt", "a")
f.write("This is the fourth line.\n")
f.close()

f = open("text.txt", "r")
print(f.read())
# Out:
# Hi, this is a text file
# This is the second line.
# This is the third line.
# This is the fourth line.

# %%
f = open("text.txt", "r")
print(f.readline())
print(f.readline())
f.close()
# Out:
# Hi, this is a text file
#
# This is the second line.

# %%
f = open("text3.txt", "w")
f.write("This is a new text file.")
f.close()

f = open("text3.txt", "r")
print(f.read())
# Out:
# This is a new text file.

# %%
import os
if os.path.exists("text3.txt"):
  os.remove("text3.txt")
else:
  print("The file does not exist")

# %%
# 1. Write a Python program that reads this file and displays the content in a readable format, 
#    showing the name of the student, their age, and grade in a well-structured manner.

# 2. Write a Python function add_student that adds a new student's name, age, and grade to the students.txt file.


def st_details():
    f = open("text2.txt", "r")
    lines = f.readlines()
    for i in lines:
        a,b,c= i.strip().split(", ")
        print(f'Name: {a} , Age: {b} , Grade: {c}\n')
    
def add_student(a,b,c):
    f = open("text2.txt", "a")
    f.write(f"{a}, {b}, {c}\n")
    print(f"Student {a} added succesfully")
    f.close()

add_student("Tim",26,"B")
st_details()
# Out:
# Student Tim added succesfully
# Name: John , Age: 20 , Grade: A
#
# Name: Alice , Age: 22 , Grade: B
#
# Name: Bob , Age: 19 , Grade: C
#
# Name: Charlie , Age: 21 , Grade: A
#
# Name: David , Age: 23 , Grade: B
#
# Name: Tim , Age: 26 , Grade: B
#
# Name: Tim , Age: 26 , Grade: B
#
# Name: Tim , Age: 26 , Grade: B
#
# Name: Tim , Age: 26 , Grade: B

# %%
import csv

data = [["tommy",5,"G-S"],
["jerry",4,"S-D"]]

with open("data.csv", "a") as a:
    write = csv.writer(a)
    write.writerows(data)

# %%
with open("data.csv", "r") as b:
    read = csv.reader(b)
    for i in read:
        print(i)
# Out:
# ['tommy', '5', 'G-S']
# ['jerry', '4', 'S-D']

# %%
# Write a Python program to copy the contents of one file into another file.

with open("text2.txt", "r") as a:
    b = a.read()
    
with open("text.txt", "a") as c:
    c.write(f"{b}\n")

# %%
# Write a Python program that reads a file and counts the number of words, lines, and characters in it.

with open("text.txt","r") as a:
    b = a.read()
    c = (b.split())
    print(f"Number of words in current text file are {len(c)}")

with open("text.txt", "r") as d:
    e = d.readlines()
    print(f"Number of lines in current text file is {len(e)}")

with open("text.txt", "r") as f:
    g = f.read()
    h = g.replace(" ", "")
    print(len(h)- len(e))
# Out:
# Number of words in current text file are 16
# Number of lines in current text file is 3
# 57
